# %%
# About this Dataset 
# https://data.novascotia.ca/Population-and-Demographics/Average-Annual-Numbers-and-Rates-of-Suicide-Fatali/55ax-8cpp

# %%
library(dplyr)
library(readr)
library(ggplot2)
library(ggthemes)

# %%
df <- read_csv("https://data.novascotia.ca/api/views/55ax-8cpp/rows.csv?accessType=DOWNLOAD")
# Out:
# Parsed with column specification:
# cols(
#   `Years averaged` = col_character(),
#   Sex = col_character(),
#   `Age Group` = col_character(),
#   `Mean annual frequency` = col_double(),
#   `Mean rate per 100,000 population` = col_double()
# )

# %%
glimpse(df)
# Out:
# Observations: 16
# Variables: 5
# $ `Years averaged`                   <chr> "2013-2016", "2013-2016", "2013-...
# $ Sex                                <chr> "Male", "Male", "Male", "Male", ...
# $ `Age Group`                        <chr> "0-19", "20-44", "45-59", "60+",...
# $ `Mean annual frequency`            <dbl> 5.3, 33.0, 33.0, 23.3, 2.8, 9.0,...
# $ `Mean rate per 100,000 population` <dbl> 5.6, 22.3, 30.6, 21.1, 3.1, 6.1,...

# %%
names(df) <- c("Years_averaged", "Sex", "Age_Group", "Mean_annual_frequency", "Mean_rate_per_100K_population")

# %%
df
# Out:
#    Years_averaged Sex    Age_Group Mean_annual_frequency
# 1  2013-2016      Male   0-19       5.3
# 2  2013-2016      Male   20-44     33.0
# 3  2013-2016      Male   45-59     33.0
# 4  2013-2016      Male   60+       23.3
# 5  2013-2016      Female 0-19       2.8
# 6  2013-2016      Female 20-44      9.0
# 7  2013-2016      Female 45-59     11.3
# 8  2013-2016      Female 60+        6.8
# 9  2009-2012      Male   0-19       4.3
# 10 2009-2012      Male   20-44     30.0
# 11 2009-2012      Male   45-59     37.5
# 12 2009-2012      Male   60+       19.3
# 13 2009-2012      Female 0-19       2.8
# 14 2009-2012      Female 20-44     10.0
# 15 2009-2012      Female 45-59     11.3
# 16 2009-2012      Female 60+        3.8
#    Mean_rate_per_100K_population
# 1   5.6
# 2  22.3
# 3  30.6
# 4  21.1
# 5   3.1
# 6   6.1
# 7  10.0
# 8   5.2
# 9   4.3
# 10 19.9
# 11 34.1
# 12 19.7
# 13  2.9
# 14  6.6
# 15  9.9
# 16  3.3

# %%
df$Age_Group <- factor(df$Age_Group)

# %%
df$Sex <- factor(df$Sex)

# %%
df$Years_averaged <- factor(df$Years_averaged)

# %%
df2013_2016 <- df %>%
  filter(Years_averaged == "2013-2016")

# %%
glimpse(df2013_2016)
# Out:
# Observations: 8
# Variables: 5
# $ Years_averaged                <fct> 2013-2016, 2013-2016, 2013-2016, 2013...
# $ Sex                           <fct> Male, Male, Male, Male, Female, Femal...
# $ Age_Group                     <fct> 0-19, 20-44, 45-59, 60+, 0-19, 20-44,...
# $ Mean_annual_frequency         <dbl> 5.3, 33.0, 33.0, 23.3, 2.8, 9.0, 11.3...
# $ Mean_rate_per_100K_population <dbl> 5.6, 22.3, 30.6, 21.1, 3.1, 6.1, 10.0...

# %%
df2013_2016
# Out:
#   Years_averaged Sex    Age_Group Mean_annual_frequency
# 1 2013-2016      Male   0-19       5.3
# 2 2013-2016      Male   20-44     33.0
# 3 2013-2016      Male   45-59     33.0
# 4 2013-2016      Male   60+       23.3
# 5 2013-2016      Female 0-19       2.8
# 6 2013-2016      Female 20-44      9.0
# 7 2013-2016      Female 45-59     11.3
# 8 2013-2016      Female 60+        6.8
#   Mean_rate_per_100K_population
# 1  5.6
# 2 22.3
# 3 30.6
# 4 21.1
# 5  3.1
# 6  6.1
# 7 10.0
# 8  5.2

# %%
myplot <- ggplot(df2013_2016, aes(x = Sex, y = Mean_annual_frequency, color = Sex)) +
  geom_point() +
  facet_wrap(~ Age_Group) +
  ylab("Mean number of suicides") +
  xlab("Sex by Age Group") +
  ggtitle("Nova Scotia Average Yearly Suicides\nby Sex and Age from 2013-2016")

# %%
myplot

# %%
ggsave("myplot.png")
# Out:
# Saving 6.67 x 6.67 in image
